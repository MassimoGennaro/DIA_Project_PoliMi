# %%
from experiment_6 import *

# %%
exp1 = Experiment()

# %%
exp1.run(n_experiments=2)
exp1.plot_experiment()
# Out:
# Performing experiment:  1
# Performing experiment:  2

# %%
exp1.plot_regret()

# %%
exp1.gpts_rewards_per_experiment
# Out:
# [[872.124077858929,
#   831.9946990313317,
#   797.7920349541475,
#   691.8167513078458,
#   748.7525812826493,
#   810.9078022316096,
#   753.5496209420377,
#   804.1081738796868,
#   790.9417455527453,
#   804.4055489573925,
#   799.0962509933636,
#   640.8308164629179,
#   820.8129210922839,
#   836.4450051669136,
#   837.1456877689599,
#   838.6435478192111,
#   841.1857004655542,
#   816.0654283770255,
#   834.1829275555637,
#   774.3255650616018,
#   810.5135742457151,
#   828.1710796139671,
#   827.8750417061672,
#   764.0436831577877,
#   807.8284252452295,
#   815.0480841350627,
#   824.1387083773642,
#   777.3658806991187,
#   770.0261931521363,
#   817.2893042837584,
#   782.2333940449912,
#   818.5930293835004,
#   802.5067074639675,
#   820.7257839589672,
#   755.2967557076402,
#   805.1798330778378,
#   803.0116213113922,
#   827.1946858192752,
#   823.1304584213227,
#   808.0871417683467,
#   816.0361401224354,
#   816.0475108351847,
#   814.0809201778238,
# ...
