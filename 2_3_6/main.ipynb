# %%
from experiment import *
from ns_experiment import *

# %%
## config 
max_budget = 5.0
n_arms = 6
n_experiments= 10
env_id = 0

sample_factor = 8
horizon= 14*sample_factor

# %% [markdown]
# ## Stationary Experiment

# %%
exp1 = Experiment(max_budget, n_arms, env_id)
exp1.run(n_experiments, horizon)
# Out:
# Performing experiment:  1
# Performing experiment:  2
# Performing experiment:  3
# Performing experiment:  4
# Performing experiment:  5
# Performing experiment:  6
# Performing experiment:  7
# Performing experiment:  8
# Performing experiment:  9
# Performing experiment:  10

# %%
exp1.plot_regret()

# %%
exp1.plot_experiment()

# %% [markdown]
# ## Non-Stationary Experiment

# %% [markdown]
# ### Estimating kernel hyperparameters using first phase

# %%
exp2 = NonStationaryExperiment(max_budget, n_arms, sample_factor, env_id, estimate_hyperparam= True)
exp2.run(n_experiments, horizon)
# Out:
# Performing experiment:  1
# Performing experiment:  2
# Performing experiment:  3
# Performing experiment:  4
# Performing experiment:  5
# Performing experiment:  6
# Performing experiment:  7
# Performing experiment:  8
# Performing experiment:  9
# Performing experiment:  10

# %%
exp2.plot_regret()

# %%
exp2.plot_experiment()

# %% [markdown]
# ### Not estimating kernel hyperparameters before but use built-in optimizer during training

# %%
exp3 = NonStationaryExperiment(max_budget, n_arms, sample_factor, env_id)
exp3.run(n_experiments, horizon)
# Out:
# Performing experiment:  1
# Performing experiment:  2
# Performing experiment:  3
# Performing experiment:  4
# Performing experiment:  5
# Performing experiment:  6
# Performing experiment:  7
# Performing experiment:  8
# Performing experiment:  9
# Performing experiment:  10

# %%
exp3.plot_regret()

# %%
exp3.plot_experiment()

# %% [markdown]
# As we can see the regret is slightly better in the latter case, even if the training time is much higher
