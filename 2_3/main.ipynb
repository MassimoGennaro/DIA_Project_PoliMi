# %%
from experiment import *

# %%
exp2 = Experiment(max_budget= 5.0)
exp2.run()
# Out:
# experiment:  1
# experiment:  2
# experiment:  3
# experiment:  4
# experiment:  5
# experiment:  6
# experiment:  7
# experiment:  8
# experiment:  9
# experiment:  10

# %%
exp2.plot_experiment()

# %%
exp2.plot_regret()
