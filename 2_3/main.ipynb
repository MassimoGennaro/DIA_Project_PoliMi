# %%
from experiment import *

exp = Experiment()
exp.run()
# Out:
# experiment:  1
# experiment:  2
# experiment:  3

# %%
exp.plot()

# %%
exp2 = Experiment(sigma=10, max_budget= 10, n_exp= 10, horizon=40)
exp2.run()
exp.plot()
# Out:
# experiment:  1
# experiment:  2
# experiment:  3
# experiment:  4
# experiment:  5
# experiment:  6
# experiment:  7
# experiment:  8
# experiment:  9
# experiment:  10
