# %%
from experiment import *

# %%
exp1 = Experiment()

# %%
exp1.run(n_experiments=1)
exp1.plot_experiment()
# Out:
# Performing experiment:  1

# %%
exp1.opt_super_arm_reward
# Out:
# 1772.5153792778958
